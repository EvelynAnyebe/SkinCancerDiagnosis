# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(os.getcwd())
path = os.path.abspath('/content/drive/MyDrive/Colab Notebooks')
os.chdir(path)

print(os.getcwd())
# Out:
# /content
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# 1. Install the kaggle library

# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# 2. Make a directory named “.kaggle” to upload the API Key file to collab

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle/kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                                title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# victorsoeiro/netflix-tv-shows-and-movies                           Netflix TV Shows and Movies                           2MB  2022-05-15 00:01:23          15419        450  1.0
# ruchi798/data-science-job-salaries                                 Data Science Job Salaries                             7KB  2022-06-15 08:59:12           4139        147  1.0
# zusmani/petrolgas-prices-worldwide                                 Petrol/Gas Prices Worldwide                          10KB  2022-06-24 01:25:33           1877         89  1.0
# ...

# %% [markdown]
# ### Get metafiles from Kaggle

# %%
! kaggle competitions download siim-isic-melanoma-classification -f train.csv
# Out:
# ...
#   0% 0.00/339k [00:00<?, ?B/s]
# 100% 339k/339k [00:00<00:00, 30.4MB/s]

# %%
! kaggle competitions download siim-isic-melanoma-classification -f test.csv
# Out:
# ...
#   0% 0.00/479k [00:00<?, ?B/s]
# 100% 479k/479k [00:00<00:00, 44.4MB/s]

# %%
! unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
# ! kaggle competitions download -c siim-isic-melanoma-classification requires 116.6GiB so jpeg folder was downloaded
